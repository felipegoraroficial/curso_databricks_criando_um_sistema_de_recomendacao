# %%
# carregando o arquivo data_by_artist.csv
df_data_artist = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_artist.csv")

df_data_artist = df_data_artist.pandas_api()

df_data_artist[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','popularity']] = df_data_artist[['acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence','popularity']].astype(float)

# remoção dos mesmos caracteres para manter um padrão entre os datasetes
df_data_artist['artists'] = df_data_artist['artists'].str.replace('[','')
df_data_artist['artists'] = df_data_artist['artists'].str.replace(']','')
df_data_artist['artists'] = df_data_artist['artists'].str.replace("'", "")
df_data_artist['artists'] = df_data_artist['artists'].str.replace('"', '')
df_data_artist['artists'] = df_data_artist['artists'].str.replace(",", ";")

# salvando um CSV em parquet
path="dbfs:/FileStore/dados_transformados/data_artist.parquet"
df_data_artist.to_parquet(path)

# %%
# carregando o arquivo data_by_genres.csv

df_data_genres = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_genres.csv")

df_data_genres = df_data_genres.pandas_api()

df_data_genres[['acousticness', 'danceability', 'duration_ms','energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']] = df_data_genres[['acousticness', 'danceability', 'duration_ms','energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']].astype(float)

# salvando um CSV em parquet
path="dbfs:/FileStore/dados_transformados/data_genres.parquet"
df_data_genres.to_parquet(path)

# %%
# carregando o arquivo data_by_year.csv

df_data_year = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.option("sep", ',') \
.load("dbfs:/FileStore/dados/data_by_year.csv")

df_data_year = df_data_year.pandas_api()

df_data_year[['acousticness', 'danceability', 'duration_ms', 'energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo','valence', 'popularity']] = df_data_year[['acousticness', 'danceability', 'duration_ms', 'energy','instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo','valence', 'popularity']].astype(float)

# salvando um CSV em parquet
path="dbfs:/FileStore/dados_transformados/data_year.parquet"
df_data_year.to_parquet(path)

# %%
# carregando o arquivo data_w_genres.csv

df_data_Wgenres = spark.read.format('csv') \
.option("inferSchema", 'True') \
.option("header", 'True') \
.load("dbfs:/FileStore/dados/data_w_genres.csv")

df_data_Wgenres = df_data_Wgenres.pandas_api()

df_data_Wgenres[['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']] = df_data_Wgenres[['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness','tempo', 'valence', 'popularity']].astype(float)

df_data_Wgenres[['key', 'mode', 'count']] = df_data_Wgenres[['key', 'mode', 'count']].astype(int)

# remoção dos mesmos caracteres para manter um padrão entre os datasetes
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace('[','')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace(']','')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace("'", "")
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace('"', '')
df_data_Wgenres['artists'] = df_data_Wgenres['artists'].str.replace(",", ";")

# remoção dos mesmos caracteres para manter um padrão entre os datasetes
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace('[','')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace(']','')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace("'", "")
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace('"', '')
df_data_Wgenres['genres'] = df_data_Wgenres['genres'].str.replace(",", ";")


# salvando um CSV em parquet
path="dbfs:/FileStore/dados_transformados/data_w_genres.parquet"
df_data_Wgenres.to_parquet(path)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=4306177860541438#setting/sparkui/0418-101503-oy9k0ai9/driver-971287559788652260">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dbutils.fs.ls("dbfs:/FileStore/dados")
# Out:
# Out[2]: [FileInfo(path='dbfs:/FileStore/dados/data.csv', name='data.csv', size=29654587, modificationTime=1681365185000),
#  FileInfo(path='dbfs:/FileStore/dados/data_by_artist.csv', name='data_by_artist.csv', size=4315607, modificationTime=1681365076000),
#  FileInfo(path='dbfs:/FileStore/dados/data_by_genres.csv', name='data_by_genres.csv', size=576456, modificationTime=1681365079000),
#  FileInfo(path='dbfs:/FileStore/dados/data_by_year.csv', name='data_by_year.csv', size=21194, modificationTime=1681365079000),
#  FileInfo(path='dbfs:/FileStore/dados/data_w_genres.csv', name='data_w_genres.csv', size=5224673, modificationTime=1681365102000)]

# %%
df_data = spark.read.format("csv")\
                .option("inferSchema", 'True')\
                .option("header", "True")\
                .load('dbfs:/FileStore/dados/data.csv')

# %%
display(df_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type(df_data)
# Out:
# Out[5]: pyspark.sql.dataframe.DataFrame

# %%
df_data = df_data.pandas_api()

# %%
type(df_data)
# Out:
# Out[7]: pyspark.pandas.frame.DataFrame

# %%
df_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0594</td>
#       <td>1921</td>
#       <td>0.982</td>
# ...

# %%
df_data.info()
# Out:
# <class 'pyspark.pandas.frame.DataFrame'>
# Int64Index: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int32
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  object
#  5   duration_ms       170653 non-null  object
#  6   energy            170653 non-null  object
#  7   explicit          170653 non-null  object
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  object
#  10  key               170653 non-null  object
#  11  liveness          170653 non-null  object
#  12  loudness          170653 non-null  object
#  13  mode              170653 non-null  object
#  14  name              170653 non-null  object
# ...

# %%
df_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.528587</td>
#       <td>1976.787241</td>
#       <td>0.502115</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.263171</td>
#       <td>25.917853</td>
#       <td>0.376032</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>1921.000000</td>
#       <td>0.000000</td>
#     </tr>
# ...

# %%
df_data["duration_ms"] = df_data["duration_ms"].astype(int)

# %%
df_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>duration_ms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>1.704540e+05</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.528587</td>
#       <td>1976.787241</td>
#       <td>0.502115</td>
#       <td>2.304044e+05</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.263171</td>
#       <td>25.917853</td>
#       <td>0.376032</td>
#       <td>1.263665e+05</td>
#     </tr>
#     <tr>
# ...

# %%
df_data[['valence', 'acousticness', 'danceability', 'energy', 'explicit', 'instrumentalness', 'liveness', 'loudness', 'popularity', 'tempo']] = df_data[['valence', 'acousticness', 'danceability', 'energy', 'explicit', 'instrumentalness', 'liveness', 'loudness', 'popularity', 'tempo']].astype(float)

df_data[['duration_ms', 'mode', 'key']] = df_data[['duration_ms', 'mode', 'key']].astype(int)

# %%
df_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>popularity</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170080.000000</td>
#       <td>1.704540e+05</td>
#       <td>1.705730e+05</td>
# ...

# %%
df_data.info()
# Out:
# <class 'pyspark.pandas.frame.DataFrame'>
# Int64Index: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int32
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170080 non-null  float64
#  5   duration_ms       170454 non-null  int64
#  6   energy            170573 non-null  float64
#  7   explicit          170606 non-null  float64
#  8   id                170653 non-null  object
#  9   instrumentalness  170270 non-null  float64
#  10  key               170451 non-null  int64
#  11  liveness          170613 non-null  float64
#  12  loudness          170621 non-null  float64
#  13  mode              170635 non-null  int64
#  14  name              170653 non-null  object
# ...

# %%
x = df_data.loc[0:10]
x
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0594</td>
#       <td>1921</td>
#       <td>0.982</td>
# ...

# %%
x = df_data.loc[0:10]
x
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0594</td>
#       <td>1921</td>
#       <td>0.982</td>
# ...

# %%
x['artists'] = x['artists'].str.replace("\[|\]|\'", "")
x['artists'] = x['artists'].str.replace(",", ";")
x
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0594</td>
#       <td>1921</td>
#       <td>0.982</td>
# ...

# %%
df_data['artists'] = df_data['artists'].str.replace("\[|\]|\'", "")
df_data['artists'] = df_data['artists'].str.replace(",", ";")
df_data.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0594</td>
#       <td>1921</td>
#       <td>0.982</td>
# ...

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/dados_transformados")
# Out:
# Out[20]: True

# %%
dbutils.fs.ls("dbfs:/FileStore")
# Out:
# Out[21]: [FileInfo(path='dbfs:/FileStore/dados/', name='dados/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/', name='dados_transformados/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/', name='tables/', size=0, modificationTime=0)]

# %%
df_data.to_parquet("dbfs:/FileStore/dados_transformados/data.parquet")

# %%
 dbutils.fs.ls("dbfs:/FileStore/dados_transformados")
# Out:
# Out[37]: [FileInfo(path='dbfs:/FileStore/dados_transformados/data.parquet/', name='data.parquet/', size=0, modificationTime=0)]

# %%
import pyspark.pandas as ps

# %%
path = 'dbfs:/FileStore/dados_transformados/data.parquet/'
df_data = ps.read_parquet(path)
df_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.917</td>
#       <td>1970</td>
#       <td>0.096000</td>
# ...

# %%
df_data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>popularity</th>
#       <th>tempo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170653.000000</td>
#       <td>170080.000000</td>
#       <td>1.704540e+05</td>
#       <td>1.705730e+05</td>
# ...

# %%
len(df_data.year.unique())
# Out:
# Out[41]: 100

# %%
df_data.year.value_counts()
# Out:
# Out[42]: 2018    2103
# 2020    2030
# 2011    2017
# 2010    2016
# 2014    2005
# 2001    2005
# 1990    2000
# 1975    2000
# 1977    2000
# 1974    2000
# 1955    2000
# 1978    2000
# 1952    2000
# 1956    2000
# 1997    2000
# 1994    2000
# 1968    2000
# 1951    2000
# 1973    2000
# 1979    2000
# 1971    2000
# 1950    2000
# 1949    2000
# 1966    2000
# 1969    2000
# 1982    2000
# 1945    2000
# 1989    2000
# 1996    2000
# 1998    2000
# 1963    2000
# 1985    2000
# 1970    2000
# 1995    2000
# 1972    2000
# 1992    2000
# 1958    2000
# 1983    2000
# 1954    2000
# 1984    2000
# 1981    2000
# 1986    2000
# 1976    2000
# 1940    2000
# 2002    2000
# 1993    2000
# 1967    1999
# 2017    1992
# 2013    1976
# 2015    1974
# 2004    1966
# 2009    1960
# 2000    1956
# 2008    1955
# 2003    1954
# 1999    1951
# 1959    1950
# 2007    1950
# 2006    1950
# 1988    1950
# 1991    1950
# 1957    1950
# 1965    1950
# 1987    1950
# 1980    1950
# 1953    1950
# ...

# %%
df_data.year.value_counts().sort_index()
# Out:
# Out[43]: 1921     150
# 1922      71
# 1923     185
# 1924     236
# 1925     278
# 1926    1378
# 1927     615
# 1928    1261
# 1929     952
# 1930    1924
# 1931     966
# 1932     502
# 1933     691
# 1934     578
# 1935    1518
# 1936    1100
# 1937     657
# 1938     613
# 1939    1000
# 1940    2000
# 1941     960
# 1942    1682
# 1943     710
# 1944     752
# 1945    2000
# 1946    1724
# 1947    1650
# 1948    1900
# 1949    2000
# 1950    2000
# 1951    2000
# 1952    2000
# 1953    1950
# 1954    2000
# 1955    2000
# 1956    2000
# 1957    1950
# 1958    2000
# 1959    1950
# 1960    1850
# 1961    1900
# 1962    1900
# 1963    2000
# 1964    1950
# 1965    1950
# 1966    2000
# 1967    1999
# 1968    2000
# 1969    2000
# 1970    2000
# 1971    2000
# 1972    2000
# 1973    2000
# 1974    2000
# 1975    2000
# 1976    2000
# 1977    2000
# 1978    2000
# 1979    2000
# 1980    1950
# 1981    2000
# 1982    2000
# 1983    2000
# 1984    2000
# 1985    2000
# 1986    2000
# ...

# %%
df_data.year.value_counts().sort_index().plot.bar()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_data['decade'] = df_data.year.apply(lambda year: f'{(year//10)*10}s')

# %%
df_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>valence</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>explicit</th>
#       <th>id</th>
#       <th>instrumentalness</th>
#       <th>key</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>mode</th>
#       <th>name</th>
#       <th>popularity</th>
#       <th>release_date</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#       <th>decade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.917</td>
#       <td>1970</td>
# ...

# %%
df_data_2 = df_data[['decade']]
df_data_2['qtd'] = 1

# %%
df_data_2 = df_data_2.groupby('decade').sum()
df_data_2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>qtd</th>
#     </tr>
#     <tr>
#       <th>decade</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1970s</th>
#       <td>20000</td>
#     </tr>
#     <tr>
#       <th>2000s</th>
#       <td>19646</td>
#     </tr>
#     <tr>
#       <th>1980s</th>
#       <td>19850</td>
#     </tr>
#     <tr>
#       <th>1960s</th>
#       <td>19549</td>
#     </tr>
#     <tr>
#       <th>1930s</th>
#       <td>9549</td>
#     </tr>
#     <tr>
#       <th>2010s</th>
#       <td>19774</td>
#     </tr>
#     <tr>
#       <th>2020s</th>
#       <td>2030</td>
#     </tr>
#     <tr>
# ...

# %%
df_data_2.sort_index().plot.bar(y='qtd')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 dbutils.fs.ls("dbfs:/FileStore/dados_transformados")
# Out:
# Out[60]: [FileInfo(path='dbfs:/FileStore/dados_transformados/data.parquet/', name='data.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_artist.parquet/', name='data_artist.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_genres.parquet/', name='data_genres.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_w_genres.parquet/', name='data_w_genres.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_year.parquet/', name='data_year.parquet/', size=0, modificationTime=0)]

# %%
path = 'dbfs:/FileStore/dados_transformados/data_year.parquet'
df_year = ps.read_parquet(path)
df_year.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mode</th>
#       <th>year</th>
#       <th>acousticness</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>instrumentalness</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#       <th>valence</th>
#       <th>popularity</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1921</td>
#       <td>0.886896</td>
#       <td>0.418597</td>
#       <td>260537.166667</td>
#       <td>0.231815</td>
#       <td>0.344878</td>
# ...

# %%
len(df_year.year.unique())
# Out:
# Out[62]: 100

# %%
df_year.plot.line(x='year', y='duration_ms')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_year.plot.line(x='year', y=['acousticness', 'danceability', 'energy',
       'instrumentalness', 'liveness', 'speechiness', 'valence'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Perguntas
# * 1 - Quais são os 10 top artistas ?
# * 2 - Qual o gênero musical dos 10 top artistas ?
# * 3 - Quais são os 10 top gêneros ?
# * 4 - Quais artistas então nos 10 top gêneros

# %%
 dbutils.fs.ls("dbfs:/FileStore/dados_transformados")
# Out:
# Out[65]: [FileInfo(path='dbfs:/FileStore/dados_transformados/data.parquet/', name='data.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_artist.parquet/', name='data_artist.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_genres.parquet/', name='data_genres.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_w_genres.parquet/', name='data_w_genres.parquet/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/dados_transformados/data_year.parquet/', name='data_year.parquet/', size=0, modificationTime=0)]

# %%
df_genres = ps.read_parquet('dbfs:/FileStore/dados_transformados/data_genres.parquet/')
df_artists = ps.read_parquet('dbfs:/FileStore/dados_transformados/data_artist.parquet/')
df_Wgenres = ps.read_parquet('dbfs:/FileStore/dados_transformados/data_w_genres.parquet')

# %%
df_artists.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mode</th>
#       <th>count</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>instrumentalness</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#       <th>valence</th>
#       <th>popularity</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>9</td>
#       <td>0.590111</td>
#       <td>Cats 1981 Original London Cast</td>
#       <td>0.467222</td>
#       <td>250318.555556</td>
# ...

# %%
artista_ordenado = df_artists.sort_values(by='count', ascending=False)
artista_ordenado.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mode</th>
#       <th>count</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>instrumentalness</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#       <th>valence</th>
#       <th>popularity</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8367</th>
#       <td>1</td>
#       <td>3169</td>
#       <td>0.984282</td>
#       <td>Francisco Canaro</td>
#       <td>0.659676</td>
#       <td>176986.345850</td>
# ...

# %%
top_artista = artista_ordenado.iloc[0:10]
top_artista
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mode</th>
#       <th>count</th>
#       <th>acousticness</th>
#       <th>artists</th>
#       <th>danceability</th>
#       <th>duration_ms</th>
#       <th>energy</th>
#       <th>instrumentalness</th>
#       <th>liveness</th>
#       <th>loudness</th>
#       <th>speechiness</th>
#       <th>tempo</th>
#       <th>valence</th>
#       <th>popularity</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8367</th>
#       <td>1</td>
#       <td>3169</td>
#       <td>0.984282</td>
#       <td>Francisco Canaro</td>
#       <td>0.659676</td>
#       <td>176986.345850</td>
# ...

# %%
plot_title = 'Top 10 Artistas'
top_artista.plot.bar(x='count', y = 'artists', title = plot_title)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lista_artistas = top_artista.artists.unique().to_list()
lista_artistas
# Out:
# Out[71]: ['Francisco Canaro',
#  'Эрнест Хемингуэй',
#  'Эрих Мария Ремарк',
#  'Frank Sinatra',
#  'Ignacio Corsini',
#  'Vladimir Horowitz',
#  'Arturo Toscanini',
#  'Billie Holiday',
#  'Johnny Cash',
#  'Elvis Presley']

# %%
artista_genero = df_Wgenres.loc[df_Wgenres['artists'].isin(lista_artistas)]
artista_genero = artista_genero[['genres', 'artists']]
display(artista_genero)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
